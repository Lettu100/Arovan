# %% [markdown]
# <a href="https://colab.research.google.com/github/Lettu100/Arovan/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-40bfc64c-2abe-48da-b8ef-2000ab04c892" name="files[]" multiple disabled />
#      <output id="result-40bfc64c-2abe-48da-b8ef-2000ab04c892">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kiva_loans_ke.csv to kiva_loans_ke (1).csv

# %%
import io

# %%
import pandas as pd

# %%
df=pd.read_csv(io.BytesIO(uploaded['kiva_loans_ke.csv']))

# %%
df
# Out:
#             id  funded_amount  ...  repayment_interval        date
# 0      1080148            250  ...           irregular  2014-01-01
# 1       653185            250  ...           irregular  2014-01-02
# 2       653237            250  ...           irregular  2014-01-02
# 3       653229            250  ...           irregular  2014-01-02
# 4      1080150            125  ...           irregular  2014-01-02
# 5       653247            250  ...           irregular  2014-01-02
# 6       653345            600  ...           irregular  2014-01-02
# 7       653314            350  ...           irregular  2014-01-02
# 8       653159            250  ...           irregular  2014-01-02
# 9      1080151            125  ...           irregular  2014-01-02
# 10      653203            250  ...           irregular  2014-01-02
# 11      653245            250  ...           irregular  2014-01-02
# 12      653306            250  ...           irregular  2014-01-02
# ...

# %%
df.head()
# Out:
#         id  funded_amount  ...  repayment_interval        date
# 0  1080148            250  ...           irregular  2014-01-01
# 1   653185            250  ...           irregular  2014-01-02
# 2   653237            250  ...           irregular  2014-01-02
# 3   653229            250  ...           irregular  2014-01-02
# 4  1080150            125  ...           irregular  2014-01-02
#
# [5 rows x 20 columns]

# %%
df.describe()
# Out:
#                  id  funded_amount  ...  term_in_months  lender_count
# count  7.582500e+04   75825.000000  ...    75825.000000  75825.000000
# mean   1.011230e+06     425.300429  ...       12.630373     13.547498
# std    1.838386e+05     711.282336  ...        7.812868     20.891424
# min    6.531570e+05       0.000000  ...        1.000000      0.000000
# 25%    8.636530e+05     200.000000  ...        9.000000      6.000000
# 50%    1.033706e+06     300.000000  ...       13.000000     10.000000
# 75%    1.155746e+06     500.000000  ...       14.000000     17.000000
# max    1.340339e+06   50000.000000  ...      122.000000   1589.000000
#
# [8 rows x 6 columns]

# %%
df.describe(include)
# Out:
#                  id  funded_amount  ...  term_in_months  lender_count
# count  7.582500e+04   75825.000000  ...    75825.000000  75825.000000
# mean   1.011230e+06     425.300429  ...       12.630373     13.547498
# std    1.838386e+05     711.282336  ...        7.812868     20.891424
# min    6.531570e+05       0.000000  ...        1.000000      0.000000
# 25%    8.636530e+05     200.000000  ...        9.000000      6.000000
# 50%    1.033706e+06     300.000000  ...       13.000000     10.000000
# 75%    1.155746e+06     500.000000  ...       14.000000     17.000000
# max    1.340339e+06   50000.000000  ...      122.000000   1589.000000
#
# [8 rows x 6 columns]
